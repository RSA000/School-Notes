# %% [markdown]
# ### Python Programs
#
# Program author: Richard Sullivan Andison
#
# ID#: 3634206

# %%
# Program 1 - Math Functions

# Printing Out Credentials

print("Program author: Richard Sullivan Andison \nID#: 3634206 \nProgram 1: Math Functions \n ")

# This program shows the use of six math functions


# Creating number variable to use for all math functions

# Creating first number variable
number_1 = 2
# Creating second number variable
number_2 = 2

# Each example follows the same instructions
# The programs prints out a fstring displaying 
# the two numbers and the result of adding subtracting etc..

# Addition Example
print(f'Addition: {number_1} + {number_2} = {number_1 + number_2}')

# Subtraction
print(f'Subtraction: {number_1} - {number_2} = {number_1 - number_2}')

# Multiplication
print(f'Multiplication: {number_1} x {number_2} = {number_1 * number_2}')

# Division
print(f'Division: {number_1} / {number_2} = {number_1 / number_2}')

# Exponent
print(f'Exponents: {number_1} ** {number_2} = {number_1 ** number_2}')

# Remainder (modulo)
print(f'Remainder/Modulo: {number_1} % {number_2} = {number_1 % number_2}')
# Out:
# Program author: Richard Sullivan Andison
# ID#: 3634206
# Program 1: Math Functions
#
# Addition: 2 + 2 = 4
# Subtraction: 2 - 2 = 0
# Multiplication: 2 x 2 = 4
# Division: 2 / 2 = 1.0
# Exponents: 2 ** 2 = 4
# Remainder/Modulo: 2 % 2 = 0

# %%
# Program 2 Using Input

# Printing Out Credentials

print("Program author: Richard Sullivan Andison \nID#: 3634206 \nProgram 2: Using Input \n ")

# Creating an empty list to store strings/integers
lst_str = []
lst_int = []

# Creating a while loop that asks for input until user has entered the correct data
# While the length of the list is less than 2
# ask user for input of string
while len(lst_str) < 2:
    # The string variable is assigned to the input of the user. 
    # All user input is converted to a string datatype
    string = str(input(f"Please input a string #{len(lst_str) + 1}: "))
    # The string variable must be alphabetical 
    if string.isalpha():
        # If the string variable is alphabetical, append to lst
        lst_str.append(string)
    else:
        # Otherwise, print (invalid input try again) and start the loop over
        print("invalid input, try again: ")

# Next, we can do the same thing for the integers

# while the length of the list is less than 4
# ask user for input of integer
while len(lst_int) < 2:
    # The integer variable is assigned to the input of the user
    # all user input is converted to an int type
    try:
        integer = int(input(f"Please input integer # {len(lst_int) + 1}"))
        # If there is a value error (integer not entered) prompt user to try again.
    except ValueError:
        print("invalid input, try again: ")
        # continue resets the loop to the beginning
        continue
    # If the input is indeed a number, append to lst
    lst_int.append(integer)

# printing out the added strings
print(lst_str[0] + lst_str[1])
# printing out the added integers
print(lst_int[0] + lst_int[1])
# Out:
# Program author: Richard Sullivan Andison
# ID#: 3634206
# Program 1: Math Functions
#
# beanstoast
# 36

# %%
# This program prompts the user for a password. If the password is correct, the program asks for the users name and displays a message greeting the user.

print("Program author: Richard Sullivan Andison \nID#: 3634206 \nProgram 3: Loops And If Conditions \n ")

my_name = "Sullivan"
password = "hello"

while True:
    user_password = input("Please Input Password: ")
    if user_password == password:
        break
    print("Invalid password. Try again.")
print("Welcome!")

user_name = input("What is your name?: ").title()

if user_name in ["Madonna", "Cher"]:
    print("May I have your autograph, please?")
elif user_name == my_name:
    print("What a great name!")
else:
    print(f'{user_name}, that\'s a nice name')
# Out:
# Program author: Richard Sullivan Andison
# ID#: 3634206
# Program 1: Loops And If Conditions
#
# Welcome!
# What a great name!

# %%
# This program calculates the perimeter and area of rectangles, squares, and circles.
from os import system
from sys import platform

def show_menu():
    print("Program author: Richard Sullivan Andison \nID#: 3634206 \nProgram 4: Functions \n ")
    print("Calculations Menu")
    print("1: Area (Square)")
    print("2: Area (Rectangle)")
    print("3: Area (Circle)")
    print("4: Perimeter (Square)")
    print("5: Perimeter (Rectangle)")
    print("6: Perimeter (Circle)")
    print("7: Exit")

    while True:
        try:
            selection_number = int(input("Please select a calculation: "))
        except ValueError:
            print("Invalid selection")
            continue
        if selection_number > 0 and selection_number < 8:
            if platform == "linux" or platform == "darwin" or platform == "linux2":
                system('clear')
            if platform == "win32":
                system('cls')
            
            return selection_number
        print("Invalid selection")
        continue


def squarea():
    while True:
        try:  
            side = int(input("Input square side: "))
        except ValueError:
            print("Invalid input.")
            continue
        break
    print(f"The area of a square with a side length of {side} is {side * side}")


def rectarea():
    while True:
        try:  
            length = int(input("Input length: "))
        except ValueError:
            print("Invalid input.")
            continue
        try:  
            width = int(input("Input width: "))
        except ValueError:
            print("Invalid input.")
            continue
        break
    print(f"The area of a rectangle with a side length of {length} and a width of {width} is {length * width}")


def circarea():
    while True:
        try:  
            radius = int(input("Input radius: "))
        except ValueError:
            print("Invalid input.")
            continue
        break
    print(f"The area of a circle with a radius of {radius} is  {3.14 * radius**2}")


def squarimeter():
    while True:
        try:  
            side = int(input("Input side: "))
        except ValueError:
            print("Invalid input.")
            continue
        break
    print(f"The perimeter of a square with side lengths of {side} is {side * 4}")


def rectimeter():
    while True:
        try:  
            length = int(input("Input length: "))
        except ValueError:
            print("Invalid input.")
            continue
        try:  
            width = int(input("Input width: "))
        except ValueError:
            print("Invalid input.")
            continue
        break
    print(f"The perimeter of a rectangle with a length of {length} and a width of {width} is {(width * 2 )+ (length * 2)}")


def circimeter():
    while True:
        try:  
            diameter = int(input("Input radius: "))
        except ValueError:
            print("Invalid input.")
            continue
        break
    print(f"The perimeter of a circle with a diameter length of {diameter} is {3.14 * diameter}")


def calculation_selector(num):
    if num == 1:
        squarea()
    elif num == 2:
        rectarea()
    elif num == 3:
        circarea()
    elif num == 4:
        squarimeter()
    elif num == 5:
        rectimeter()
    elif num == 6:
        circimeter()
    elif num == 7:
        return 7


while True:
    if calculation_selector(show_menu()) == 7:
        print("See you next time!")
        break
# Out:
#   Cell In[56], line 128
#     print("See you next time!
#                              ^
# SyntaxError: EOL while scanning string literal
