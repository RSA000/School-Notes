# %% [markdown]
# ### Chapter 2: Algorithm Discovery and Design
#
# ##### Pseudocode
# Pseudocode is a way of representing algorithms in natural language.
#
# * Finding a solution to a given problem is called algorithm discovery.

# %% [markdown]
# ### Exercises
#
# 1. Write pseudocode instructions that carry out each of the following computational operations:
#
# a. Determine the area of a traingle given values for the base b and the height h.
#
# ``` python
# # Area = (B * H) / 2
#
# # Get values for base (B) and height (H)
# B = 10
# H = 20
#
# # Multiply base and height by eachother and divide by 2
# # Store result as area (A)
#
# A = (B * A) / 2
# ```
#
# b. Compute the interest earned in 1 year given the starting account balance B and the annual interest rate I and assuming simple interest that is, no compounding. also determine the final balance at the end of the year.
#
# ```python
# # Get values for interest (I) and starting account balance (B)
#
# # Create end of year (EOY) and set to zero
#
# I = 0.01
# B = 100
# EOY = 0
#
# # Multiply account balance by interest (B * I) and add to the original balance, store result in EOY
#
# EOY = B + (B * I)
#
# ```
#
#
#
# c. Determine the flying time between two cities given the mileage M between them and the average speed of the airplane.
#
# ```python
# # Get values for mileage
# M = 2780
#
# # Get average speed
# # For fun I'm pretending the average speed has to be calculated from a list of recorded speeds.
#
# # The recorded speeds (In MPH) will be stored as a list called speed
# speeds = [200, 250, 275, 200, 100]
#
# # Create variable for length of list (L)
# # create variable total (T) and set value to 0
# # Create variable avg_speed and set value to 0
#
# L = 5
# total = 0
# avg_speed = 0
#
# # For each number in speed, add to total
#
# for speed in speeds:
#     total = speed + total
#
# # divide total by length (L) and store avg
#
# avg_speed = total / L
#
# # Create a time (In hours) variable and set it to 0
#
# time = 0
#
# # time = distance/speed
# # Find time by dividing mileage (M) by speed (avg)
#
# time = M / avg
#
#
# ```
