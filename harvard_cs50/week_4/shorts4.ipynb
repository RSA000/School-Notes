# %% [markdown]
# ### Hexadecimal
#
# Most western cultures use a base 10 system of counting.
# Binary is base 2.
# Hexadecimal uses base 16: 123456789abcdef
#
# 16 is a power of 2 (4^2)
#
# example of place value
#
# 0x397 from right to left = 1 x 7, 9 * 16, 3 * 256
# 16^0, 16^1 16^2 ect...
#
# each hexidecimal value represents a group of 4 binary place values

# %% [markdown]
# ### Pointers
#
# * Pointers offer another way to pass data in functions
#     * Before, we passed data by its value.
#     * This creates a copy of the data and doesn't actually use the original data passed in, it creates a copy.
#     * One exception is when passing an array.
#
# * With pointers we can pass the original data itself.
#     * This means we can impact the original data
#
#
# ##### How Memory Works Recap
#
# * Every file in your computers lives in its memory (HDD - Hard Disk Drive) (SSD - Solid State Drive).
#
# * The above formats are used for storage, when we use and manipulate data, we use RAM - Random Access Memory.
#
# * Memory is basically a big array of 8-bit wide bytes.
#     * example 512 MB, 1GB, 2GB, 4GB.
#
# memory allocations
#
# * int - 4 bytes
# * char - 1 byte
# * float - 4 bytes
# * double - 8 bytes
# * long long - 8 bytes
# * string - ???
#
# Each location in memory has an address
#
# A pointer is nothing more than an address
#
# example with c
#
# int k; - allocating memory for integer
# k = 5; - putting a value of 5 in that memory
# int* pk;
# pk = &k; - putting the address of k in pk. pk **points** to k
#
# ##### What is a pointer?
#
# * A pointer is a data item whose
#     * value is a memory address
#     * type describes the data located at that memory address
#
# * Pointers allow data structures and variables to be shared among functions
#
#
# #### Types of pointers in C
#
# * Null Pointer
#     * Simplest pointer. Points to nothing which is sometimes useful
#     * When you create and pointer but do not set it a value right away, you should always set the value of the pointer to NULL.
#     * You can check if a pointer is NULL using the equality operator (==)
#
#
# * Another easy way to create a pointer is to simply extract the address of an existing variable. We use & to get a variables address.
#     * If x is an int-type variable, then &x is a pointer-to-int whose value is the address of x
#     * If arr is an array of doubles, then &arr[i] is a pointer-to-double whs value is the address of the ith element of arr
#         * An array's namm is acutally just a pointer to its first element.
#
#
# The name of an array is actually just a pointer to the first element, that's why when we pass in an array in a function and change values, the values are changed globally
#
# * The main purpose of a pointer is to allow us to modify or see the location to where it points
#     * We do this by dereferncing the pointer
#
# * If we a pointer-to-char called pc, then *pc is the data that lives at the memory address stored inside the variable pc.
#
# * In this context, \* is known as the dereference operator
#
# * It goes to the reference and accesses the data at that memory location.
#
# * You will get a segmentation fault if we try to dereference a pointer that is NULL
#     * This is good behavior which can prevent manipulation of unknown pointers
#
#
# int* p;
# * The value of p is an address
# * We can dereference p with the * operator
# * If we do, what we'll find at that location is an int
#
#
# A tricky thing with *s. They're an imporatant part of both the type name and variable name.
#
# #### How large is a string?
# Strings don't actually exist and is actually char*

# %% [markdown]
# ### Defining Custom Types
#
# * typedef allows a way to shorthand name for data types.
#
# * Essentially its to define a data type first and then alias it to something else
#
# example of typedef
#
# ```c
#
# struct car
# {
#     int year;
#     char model[10];
#     char plate[7];
#     int odemeter;
#     double engine_size;
# };
#
# typedef struct car car_t;
# ```
#
# You can also define the type between the start and end
#
# ```c
#
# typedef struct car
# {
#     int year;
#     char model[10];
#     char plate[7];
#     int odometer;
#     double engine_size;
# }
# car_t;
# ```

# %% [markdown]
# ### Dynamic Memory Allocation
#
# * We can use pointers to get access to a block of dynamically allocated memory at runtime
#
# * Dynamically allocated memory comes from a pool of memory known as the heap
#
# * In previous projects, all the our memory has come from the stack
#
# To get DAM we use the function malloc(), passing the numbers of bytes requested to its parameter
#
# * malloc() returns a pointer to that memory.
#
# * if malloc() is unable to allocate memory, it return NULL
#
# ```c
# // statically obtain an integer
# int x;
#
# // dynamically obtain an integer
# int *px = malloc(4);
#
# // array of floats on the stack
# float stack_array[x];
#
# // array of floats on the heap
# float* heap_array = malloc(x * sizeof(float));
# ```
#
# * DAM is not automatically return to the system for later use when its function finishes execution. This can cause memory leaks.
#
# * You always want to free() after your done working with your DAM
#
# Three Rules
#
# * Every block of memory that you malloc() must be free()d
# * Only memory that you malloc() should be free()d
# * Do not free() a block of memory more than once

# %% [markdown]
# ### Call Stack
#
# When you call a function, the system creates space in memory for that function to work.
# * These chunks of memory are often referred to as stack frames or function frames
#
# More than one function's stack frame may exist is memory at a given time. If main() calls move() which then calls direction(), all three functions have open frames.
#
# * These frames are arranged in a stack. The frame of the most-recently called function is always of the top of the stack.
#
# * When a new function is called, a new frame is pushed onto the top of the stack and becomes the active frame.
#
# * When a function finishes its work, its frame is popped off the stack, and the frame immediately below it becomes the new, active, function on the top of the stack. This function picks up immediately where it left off.

# %% [markdown]
# ### File Pointers
#
# * Files are the primary means of storing persistent data, data that dos not disapear when your program stop running.
#
# * The abstraction of files that C provides is implemented in a data structure known as a file
#     * Almost universally when working with files, we will be using pointers to them, FILE* for example.
#
# * All tools for working with files is contain within stdio.h
#     * example fgetc(FILE*)
#
# Some examples of functions the may be used:
# * fopen() - used to get a file pointer
#     * opens a file and returns a file pointer to it.
#     * Make sure it doesn't return NULL
#     * Example: FILE* ptr = fopen(\<filename>, \<operation>);
#     * Some operations r - read, w - write, a - append
# * fclose()
#     * Closes the file pointed to by the given file pointer
#     * example: fclose(ptr1);
# * fgetc()
#     * Reads and returns the next character from the file pointed to.
#     * Note: The operation of the file pointer passed as a parameter must be "r" for read, or an error will occur.
#     * example: char ch = fgetc(\<file pointer>)
# * fputc()
#     * Writes or appends the specified cahracter to the file
#     * Note: The operation of the file pointer passed in as a paramater must be "w" for write or "a" for append.
#     * example: fputc(\<character>, \<file pointer>);
# * fread()
#     * Reads \<qty> units of size \<size> from the file pointed to and stores them in memory in a buffer (usually an array) pointed to by \<buffer>
#     * Note: The operation of the file pointer passed in as a parameter must be "r" for read, or you will suffer an error.
#     * example: fread(\<buffer>, \<size>, \<qty>, \<file pointer>);
# * fwrite()
#     * Writes \<qty> units of size \<size> to the file pointed to be reading them from a buffer (usually an array) pointed to by \<buffer>
#     * Note: must be "w" or "a"
#     * example: fwrite(\<buffer>, \<size>, \<qty>, \<file_pointer>)
